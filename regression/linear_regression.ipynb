# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv(r"C:\Users\theju\Downloads\archive\housing.csv")
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
x = data.drop(['Price','Address'],axis=1)
y= data['Price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
coeff_df = pd.DataFrame({'features':x.columns,'Coefficent':model.coef_})

# %%
print(coeff_df)
# Out:
#                        features     Coefficent
# 0              Avg. Area Income      21.639855
# 1           Avg. Area House Age  165729.214009
# 2     Avg. Area Number of Rooms  120958.348945
# 3  Avg. Area Number of Bedrooms    1949.092535
# 4               Area Population      15.226224

# %%
plt.figure(figsize=(8,5))
plt.scatter(y_pred,y_test)
plt.xlabel("actual value")
plt.ylabel("predicted value")
plt.show()

# %%
#optional
plt.figure(figsize=(8,5))
sns.histplot((y_pred),bins=50,kde=True)
plt.xlabel("predicted error")
plt.ylabel("count")
plt.show()
